# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 

from tqdm import tqdm

# %%
Fault = 'Real'

rootdir0 = '../Data/Numpy_data/'+Fault+'/Training/Normal'
rootdir1 = '../Data/Numpy_data/'+Fault+'/Training/IR_FP'
rootdir2 = '../Data/Numpy_data/'+Fault+'/Training/OR_FP'
rootdir3 = '../Data/Numpy_data/'+Fault+'/Training/OR_IR_FP'
rootdir4 = '../Data/Numpy_data/'+Fault+'/Training/OR_IR_PDI'
rootdir5 = '../Data/Numpy_data/'+Fault+'/Training/OR_PDI'


list_0 = os.listdir(rootdir0) #列出文件夹下所有的目录与文件
list_1 = os.listdir(rootdir1)
list_2 = os.listdir(rootdir2)
list_3 = os.listdir(rootdir3)
list_4 = os.listdir(rootdir4)
list_5 = os.listdir(rootdir5)


T_rootdir0 = '../Data/Numpy_data/'+Fault+'/Testing/Normal'
T_rootdir1 = '../Data/Numpy_data/'+Fault+'/Testing/IR_FP'
T_rootdir2 = '../Data/Numpy_data/'+Fault+'/Testing/OR_FP'
T_rootdir3 = '../Data/Numpy_data/'+Fault+'/Testing/OR_IR_FP'
T_rootdir4 = '../Data/Numpy_data/'+Fault+'/Testing/OR_IR_PDI'
T_rootdir5 = '../Data/Numpy_data/'+Fault+'/Testing/OR_PDI'


T_list_0 = os.listdir(T_rootdir0) #列出文件夹下所有的目录与文件
T_list_1 = os.listdir(T_rootdir1)
T_list_2 = os.listdir(T_rootdir2)
T_list_3 = os.listdir(T_rootdir3)
T_list_4 = os.listdir(T_rootdir4)
T_list_5 = os.listdir(T_rootdir5)


lab0 = np.array([0])
lab1 = np.array([1])
lab2 = np.array([2])
lab3 = np.array([3])
lab4 = np.array([4])
lab5 = np.array([5])

num_train = 0 
num_test = 0

# %%
snr_num = 4
snr_str = "4_db_1"

# %%
def wgn(x, snr):
    
    snr = 10**(snr/10.0)
    xpower = np.sum(x**2)/len(x)
    npower = xpower / snr
    
    return np.random.randn(len(x)) * np.sqrt(npower)


def add_noise(data):
    
    rand_data = wgn(data, snr_num)
    
    for id in range(len(data)):
        data[id] = data[id] + rand_data[id]
    
    return data

# %%
detail_num = 0

for id_0 in range(0,len(list_0)):
    
    path = os.path.join(rootdir0,list_0[id_0])
    
    if os.path.isfile(path):
        print(path)
        
        train_data = np.load(path)
        train_data = add_noise(train_data)
                
        train_len = int((len(train_data)-5120)/5120 + 1)
        
        for sub_id in range(0, train_len):
            
            sub_train_data = train_data[sub_id*5120:sub_id*5120+5120]
            
            str_num_train = str(num_train)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/train_data/"+ str_num_train + "_train.npy", sub_train_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/train_lab/"+ str_num_train + "_lab.npy", lab0)    
            
            num_train += 1

for id_0 in range(0,len(T_list_0)):
    
    path = os.path.join(T_rootdir0,T_list_0[id_0])
    
    if os.path.isfile(path):
        print(path)
        
        test_data = np.load(path)
        train_data = add_noise(train_data)
                
        test_len = int((len(test_data)-5120)/5120 + 1)
            
        for sub_id in range(0, test_len):
            
            sub_test_data = test_data[sub_id*5120:sub_id*5120+5120]
            
            str_num_test = str(num_test)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_data/"+ str_num_test + "_test.npy", sub_test_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_lab/"+ str_num_test + "_lab.npy", lab0) 
            
            str_detail_num = str(detail_num)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_detail/0/"+ str_detail_num + "_test.npy", sub_test_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_lab_detail/0/"+ str_detail_num + "_lab.npy", lab0)       
            detail_num += 1
            
            num_test += 1
# Out:
# ../Data/Numpy_data/Real/Training/Normal\N09_M07_F10_K004_1.npy
# ../Data/Numpy_data/Real/Training/Normal\N09_M07_F10_K004_10.npy
# ../Data/Numpy_data/Real/Training/Normal\N09_M07_F10_K004_11.npy
# ../Data/Numpy_data/Real/Training/Normal\N09_M07_F10_K004_12.npy
# ../Data/Numpy_data/Real/Training/Normal\N09_M07_F10_K004_13.npy
# ../Data/Numpy_data/Real/Training/Normal\N09_M07_F10_K004_14.npy
# ../Data/Numpy_data/Real/Training/Normal\N09_M07_F10_K004_15.npy
# ../Data/Numpy_data/Real/Training/Normal\N09_M07_F10_K004_2.npy
# ../Data/Numpy_data/Real/Training/Normal\N09_M07_F10_K004_3.npy
# ../Data/Numpy_data/Real/Training/Normal\N09_M07_F10_K004_4.npy
# ../Data/Numpy_data/Real/Training/Normal\N09_M07_F10_K004_5.npy
# ../Data/Numpy_data/Real/Training/Normal\N09_M07_F10_K004_6.npy
# ../Data/Numpy_data/Real/Training/Normal\N09_M07_F10_K004_7.npy
# ../Data/Numpy_data/Real/Training/Normal\N09_M07_F10_K004_8.npy
# ../Data/Numpy_data/Real/Training/Normal\N09_M07_F10_K004_9.npy
# ...

# %%
detail_num = 0

for id_1 in range(0,len(list_1)):
    
    path = os.path.join(rootdir1,list_1[id_1])
    
    if os.path.isfile(path):
        print(path)
        
        train_data = np.load(path)
        train_data = add_noise(train_data)
                
        train_len = int((len(train_data)-5120)/5120 + 1)
        
        for sub_id in range(0, train_len):
            
            sub_train_data = train_data[sub_id*5120:sub_id*5120+5120]
            
            str_num_train = str(num_train)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/train_data/"+ str_num_train + "_train.npy", sub_train_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/train_lab/"+ str_num_train + "_lab.npy", lab1)    
            
            num_train += 1

for id_1 in range(0,len(T_list_1)):
    
    path = os.path.join(T_rootdir1,T_list_1[id_1])
    
    if os.path.isfile(path):
        print(path)
        
        test_data = np.load(path)
        train_data = add_noise(train_data)
                
        test_len = int((len(test_data)-5120)/5120 + 1)
            
        for sub_id in range(0, test_len):
            
            sub_test_data = test_data[sub_id*5120:sub_id*5120+5120]
            
            str_num_test = str(num_test)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_data/"+ str_num_test + "_test.npy", sub_test_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_lab/"+ str_num_test + "_lab.npy", lab1) 
            
            str_detail_num = str(detail_num)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_detail/1/"+ str_detail_num + "_test.npy", sub_test_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_lab_detail/1/"+ str_detail_num + "_lab.npy", lab1)       
            detail_num += 1
            
            num_test += 1
# Out:
# ../Data/Numpy_data/Real/Training/IR_FP\N09_M07_F10_KI04_1.npy
# ../Data/Numpy_data/Real/Training/IR_FP\N09_M07_F10_KI04_10.npy
# ../Data/Numpy_data/Real/Training/IR_FP\N09_M07_F10_KI04_11.npy
# ../Data/Numpy_data/Real/Training/IR_FP\N09_M07_F10_KI04_12.npy
# ../Data/Numpy_data/Real/Training/IR_FP\N09_M07_F10_KI04_13.npy
# ../Data/Numpy_data/Real/Training/IR_FP\N09_M07_F10_KI04_14.npy
# ../Data/Numpy_data/Real/Training/IR_FP\N09_M07_F10_KI04_15.npy
# ../Data/Numpy_data/Real/Training/IR_FP\N09_M07_F10_KI04_2.npy
# ../Data/Numpy_data/Real/Training/IR_FP\N09_M07_F10_KI04_3.npy
# ../Data/Numpy_data/Real/Training/IR_FP\N09_M07_F10_KI04_4.npy
# ../Data/Numpy_data/Real/Training/IR_FP\N09_M07_F10_KI04_5.npy
# ../Data/Numpy_data/Real/Training/IR_FP\N09_M07_F10_KI04_6.npy
# ../Data/Numpy_data/Real/Training/IR_FP\N09_M07_F10_KI04_7.npy
# ../Data/Numpy_data/Real/Training/IR_FP\N09_M07_F10_KI04_8.npy
# ../Data/Numpy_data/Real/Training/IR_FP\N09_M07_F10_KI04_9.npy
# ...

# %%
detail_num = 0

for id_2 in range(0,len(list_2)):
    
    path = os.path.join(rootdir2,list_2[id_2])
    
    if os.path.isfile(path):
        print(path)
        
        train_data = np.load(path)
        train_data = add_noise(train_data)
                
        train_len = int((len(train_data)-5120)/5120 + 1)
        
        for sub_id in range(0, train_len):
            
            sub_train_data = train_data[sub_id*5120:sub_id*5120+5120]
            
            str_num_train = str(num_train)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/train_data/"+ str_num_train + "_train.npy", sub_train_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/train_lab/"+ str_num_train + "_lab.npy", lab2)    
            
            num_train += 1

for id_2 in range(0,len(T_list_2)):
    
    path = os.path.join(T_rootdir2,T_list_2[id_2])
    
    if os.path.isfile(path):
        print(path)
        
        test_data = np.load(path)
        train_data = add_noise(train_data)
                
        test_len = int((len(test_data)-5120)/5120 + 1)
            
        for sub_id in range(0, test_len):
            
            sub_test_data = test_data[sub_id*5120:sub_id*5120+5120]
            
            str_num_test = str(num_test)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_data/"+ str_num_test + "_test.npy", sub_test_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_lab/"+ str_num_test + "_lab.npy", lab2) 
            
            str_detail_num = str(detail_num)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_detail/2/"+ str_detail_num + "_test.npy", sub_test_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_lab_detail/2/"+ str_detail_num + "_lab.npy", lab2)       
            detail_num += 1
            
            num_test += 1
# Out:
# ../Data/Numpy_data/Real/Training/OR_FP\N09_M07_F10_KA04_1.npy
# ../Data/Numpy_data/Real/Training/OR_FP\N09_M07_F10_KA04_10.npy
# ../Data/Numpy_data/Real/Training/OR_FP\N09_M07_F10_KA04_11.npy
# ../Data/Numpy_data/Real/Training/OR_FP\N09_M07_F10_KA04_12.npy
# ../Data/Numpy_data/Real/Training/OR_FP\N09_M07_F10_KA04_13.npy
# ../Data/Numpy_data/Real/Training/OR_FP\N09_M07_F10_KA04_14.npy
# ../Data/Numpy_data/Real/Training/OR_FP\N09_M07_F10_KA04_15.npy
# ../Data/Numpy_data/Real/Training/OR_FP\N09_M07_F10_KA04_2.npy
# ../Data/Numpy_data/Real/Training/OR_FP\N09_M07_F10_KA04_3.npy
# ../Data/Numpy_data/Real/Training/OR_FP\N09_M07_F10_KA04_4.npy
# ../Data/Numpy_data/Real/Training/OR_FP\N09_M07_F10_KA04_5.npy
# ../Data/Numpy_data/Real/Training/OR_FP\N09_M07_F10_KA04_6.npy
# ../Data/Numpy_data/Real/Training/OR_FP\N09_M07_F10_KA04_7.npy
# ../Data/Numpy_data/Real/Training/OR_FP\N09_M07_F10_KA04_8.npy
# ../Data/Numpy_data/Real/Training/OR_FP\N09_M07_F10_KA04_9.npy
# ...

# %%
detail_num = 0

for id_3 in range(0,len(list_3)):
    
    path = os.path.join(rootdir3,list_3[id_3])
    
    if os.path.isfile(path):
        print(path)
        
        train_data = np.load(path)
        train_data = add_noise(train_data)
                
        train_len = int((len(train_data)-5120)/5120 + 1)
        
        for sub_id in range(0, train_len):
            
            sub_train_data = train_data[sub_id*5120:sub_id*5120+5120]
            
            str_num_train = str(num_train)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/train_data/"+ str_num_train + "_train.npy", sub_train_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/train_lab/"+ str_num_train + "_lab.npy", lab3)    
            
            num_train += 1

for id_3 in range(0,len(T_list_3)):
    
    path = os.path.join(T_rootdir3,T_list_3[id_3])
    
    if os.path.isfile(path):
        print(path)
        
        test_data = np.load(path)
        train_data = add_noise(train_data)
                
        test_len = int((len(test_data)-5120)/5120 + 1)
            
        for sub_id in range(0, test_len):
            
            sub_test_data = test_data[sub_id*5120:sub_id*5120+5120]
            
            str_num_test = str(num_test)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_data/"+ str_num_test + "_test.npy", sub_test_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_lab/"+ str_num_test + "_lab.npy", lab3) 
            
            str_detail_num = str(detail_num)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_detail/3/"+ str_detail_num + "_test.npy", sub_test_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_lab_detail/3/"+ str_detail_num + "_lab.npy", lab3)       
            detail_num += 1
            
            num_test += 1
# Out:
# ../Data/Numpy_data/Real/Training/OR_IR_FP\N09_M07_F10_KB23_1.npy
# ../Data/Numpy_data/Real/Training/OR_IR_FP\N09_M07_F10_KB23_10.npy
# ../Data/Numpy_data/Real/Training/OR_IR_FP\N09_M07_F10_KB23_11.npy
# ../Data/Numpy_data/Real/Training/OR_IR_FP\N09_M07_F10_KB23_12.npy
# ../Data/Numpy_data/Real/Training/OR_IR_FP\N09_M07_F10_KB23_13.npy
# ../Data/Numpy_data/Real/Training/OR_IR_FP\N09_M07_F10_KB23_14.npy
# ../Data/Numpy_data/Real/Training/OR_IR_FP\N09_M07_F10_KB23_15.npy
# ../Data/Numpy_data/Real/Training/OR_IR_FP\N09_M07_F10_KB23_2.npy
# ../Data/Numpy_data/Real/Training/OR_IR_FP\N09_M07_F10_KB23_3.npy
# ../Data/Numpy_data/Real/Training/OR_IR_FP\N09_M07_F10_KB23_4.npy
# ../Data/Numpy_data/Real/Training/OR_IR_FP\N09_M07_F10_KB23_5.npy
# ../Data/Numpy_data/Real/Training/OR_IR_FP\N09_M07_F10_KB23_6.npy
# ../Data/Numpy_data/Real/Training/OR_IR_FP\N09_M07_F10_KB23_7.npy
# ../Data/Numpy_data/Real/Training/OR_IR_FP\N09_M07_F10_KB23_8.npy
# ...

# %%
detail_num = 0

for id_4 in range(0,len(list_4)):
    
    path = os.path.join(rootdir4,list_4[id_4])
    
    if os.path.isfile(path):
        print(path)
        
        train_data = np.load(path)
        train_data = add_noise(train_data)
                
        train_len = int((len(train_data)-5120)/5120 + 1)
        
        for sub_id in range(0, train_len):
            
            sub_train_data = train_data[sub_id*5120:sub_id*5120+5120]
            
            str_num_train = str(num_train)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/train_data/"+ str_num_train + "_train.npy", sub_train_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/train_lab/"+ str_num_train + "_lab.npy", lab4)    
            
            num_train += 1

for id_4 in range(0,len(T_list_4)):
    
    path = os.path.join(T_rootdir4,T_list_4[id_4])
    
    if os.path.isfile(path):
        print(path)
        
        test_data = np.load(path)
        train_data = add_noise(train_data)
                
        test_len = int((len(test_data)-5120)/5120 + 1)
            
        for sub_id in range(0, test_len):
            
            sub_test_data = test_data[sub_id*5120:sub_id*5120+5120]
            
            str_num_test = str(num_test)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_data/"+ str_num_test + "_test.npy", sub_test_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_lab/"+ str_num_test + "_lab.npy", lab4) 
            
            str_detail_num = str(detail_num)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_detail/4/"+ str_detail_num + "_test.npy", sub_test_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_lab_detail/4/"+ str_detail_num + "_lab.npy", lab4)       
            detail_num += 1
            
            num_test += 1
# Out:
# ../Data/Numpy_data/Real/Training/OR_IR_PDI\N09_M07_F10_KB27_1.npy
# ../Data/Numpy_data/Real/Training/OR_IR_PDI\N09_M07_F10_KB27_10.npy
# ../Data/Numpy_data/Real/Training/OR_IR_PDI\N09_M07_F10_KB27_11.npy
# ../Data/Numpy_data/Real/Training/OR_IR_PDI\N09_M07_F10_KB27_12.npy
# ../Data/Numpy_data/Real/Training/OR_IR_PDI\N09_M07_F10_KB27_13.npy
# ../Data/Numpy_data/Real/Training/OR_IR_PDI\N09_M07_F10_KB27_14.npy
# ../Data/Numpy_data/Real/Training/OR_IR_PDI\N09_M07_F10_KB27_15.npy
# ../Data/Numpy_data/Real/Training/OR_IR_PDI\N09_M07_F10_KB27_2.npy
# ../Data/Numpy_data/Real/Training/OR_IR_PDI\N09_M07_F10_KB27_3.npy
# ../Data/Numpy_data/Real/Training/OR_IR_PDI\N09_M07_F10_KB27_4.npy
# ../Data/Numpy_data/Real/Training/OR_IR_PDI\N09_M07_F10_KB27_5.npy
# ../Data/Numpy_data/Real/Training/OR_IR_PDI\N09_M07_F10_KB27_6.npy
# ../Data/Numpy_data/Real/Training/OR_IR_PDI\N09_M07_F10_KB27_7.npy
# ../Data/Numpy_data/Real/Training/OR_IR_PDI\N09_M07_F10_KB27_8.npy
# ...

# %%
detail_num = 0

for id_5 in range(0,len(list_5)):
    
    path = os.path.join(rootdir5,list_5[id_5])
    
    if os.path.isfile(path):
        print(path)
        
        train_data = np.load(path)
        train_data = add_noise(train_data)
                
        train_len = int((len(train_data)-5120)/5120 + 1)
        
        for sub_id in range(0, train_len):
            
            sub_train_data = train_data[sub_id*5120:sub_id*5120+5120]
            
            str_num_train = str(num_train)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/train_data/"+ str_num_train + "_train.npy", sub_train_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/train_lab/"+ str_num_train + "_lab.npy", lab5)    
            
            num_train += 1

for id_5 in range(0,len(T_list_5)):
    
    path = os.path.join(T_rootdir5,T_list_5[id_5])
    
    if os.path.isfile(path):
        print(path)
        
        test_data = np.load(path)
        train_data = add_noise(train_data)
                
        test_len = int((len(test_data)-5120)/5120 + 1)
            
        for sub_id in range(0, test_len):
            
            sub_test_data = test_data[sub_id*5120:sub_id*5120+5120]
            
            str_num_test = str(num_test)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_data/"+ str_num_test + "_test.npy", sub_test_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_lab/"+ str_num_test + "_lab.npy", lab5) 
            
            str_detail_num = str(detail_num)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_detail/5/"+ str_detail_num + "_test.npy", sub_test_data)
            np.save("../GB_data/"+Fault+"/noise_data/"+snr_str+"/test_lab_detail/5/"+ str_detail_num + "_lab.npy", lab5)       
            detail_num += 1
            
            num_test += 1
# Out:
# ../Data/Numpy_data/Real/Training/OR_PDI\N09_M07_F10_KA15_1.npy
# ../Data/Numpy_data/Real/Training/OR_PDI\N09_M07_F10_KA15_10.npy
# ../Data/Numpy_data/Real/Training/OR_PDI\N09_M07_F10_KA15_11.npy
# ../Data/Numpy_data/Real/Training/OR_PDI\N09_M07_F10_KA15_12.npy
# ../Data/Numpy_data/Real/Training/OR_PDI\N09_M07_F10_KA15_13.npy
# ../Data/Numpy_data/Real/Training/OR_PDI\N09_M07_F10_KA15_14.npy
# ../Data/Numpy_data/Real/Training/OR_PDI\N09_M07_F10_KA15_15.npy
# ../Data/Numpy_data/Real/Training/OR_PDI\N09_M07_F10_KA15_2.npy
# ../Data/Numpy_data/Real/Training/OR_PDI\N09_M07_F10_KA15_3.npy
# ../Data/Numpy_data/Real/Training/OR_PDI\N09_M07_F10_KA15_4.npy
# ../Data/Numpy_data/Real/Training/OR_PDI\N09_M07_F10_KA15_5.npy
# ../Data/Numpy_data/Real/Training/OR_PDI\N09_M07_F10_KA15_6.npy
# ../Data/Numpy_data/Real/Training/OR_PDI\N09_M07_F10_KA15_7.npy
# ../Data/Numpy_data/Real/Training/OR_PDI\N09_M07_F10_KA15_8.npy
# ../Data/Numpy_data/Real/Training/OR_PDI\N09_M07_F10_KA15_9.npy
# ...
